# %%
# Установка базовых зависимостей
import os

# Переходим в рабочую директорию
# %cd /kaggle/working

# Клонируем ComfyUI
# !git clone https://github.com/comfyanonymous/ComfyUI.git
# %cd ComfyUI

# Устанавливаем зависимости
# !pip install -r requirements.txt

# Создаем папки для моделей
# !mkdir -p models/diffusion_models
# !mkdir -p models/text_encoders  
# !mkdir -p models/vae

# Устанавливаем ComfyUI Manager
# %cd custom_nodes
# !git clone https://github.com/ltdrdata/ComfyUI-Manager.git
# %cd ComfyUI-Manager
# !pip install -r requirements.txt

# %%
# Переходим в папку моделей ComfyUI
# %cd /kaggle/working/ComfyUI/models

# Скачиваем основную FP8-модель (если у вас уже скачан .safetensors, пропустите этот этап)
# %cd diffusion_models
# !wget -O flux1-dev-kontext_fp8_scaled.safetensors "https://huggingface.co/Comfy-Org/flux1-kontext-dev_ComfyUI/resolve/main/split_files/diffusion_models/flux1-dev-kontext_fp8_scaled.safetensors"

# Скачиваем текстовые энкодеры
# %cd ../text_encoders
# !wget -O clip_l.safetensors "https://huggingface.co/comfyanonymous/flux_text_encoders/resolve/main/clip_l.safetensors"
# !wget -O t5xxl_fp8_e4m3fn_scaled.safetensors "https://huggingface.co/comfyanonymous/flux_text_encoders/resolve/main/t5xxl_fp8_e4m3fn_scaled.safetensors"

# Скачиваем VAE из открытого источника (альтернатива, работает БЕЗ авторизации)
# %cd ../vae
# !wget -O ae.safetensors "https://huggingface.co/StableDiffusionVN/Flux/resolve/main/Vae/flux_vae.safetensors"

# %%
# Перейдите в корень рабочей директории
# %cd /kaggle/working

# Скачайте скрипт для туннеля и установите openssh-клиент (можно пропустить если уже выполнено ранее)
# !wget https://raw.githubusercontent.com/wandaweb/jupyter-webui-tunneling/main/pinggy.py
# !apt-get update
# !apt-get install -y openssh-client

# Запустите ComfyUI с pinggy-туннелем для внешнего GUI
# %cd /kaggle/working/ComfyUI
# !python /kaggle/working/pinggy.py --command='python /kaggle/working/ComfyUI/main.py' --port=8188
